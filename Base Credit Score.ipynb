# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/v5_base_mini_processada.csv", sep='\t')

# %%
df.head()
# Out:
#     CHAVE  IND_BOM_CLI  COMPARATIVO_RENDA_CEP  EXPOSICAO_EMAIL  \
# 0  170033            1                    1.0           0.5652
# 1   76292            1                    1.0           0.2174
# 2    5808            1                    1.0           1.0000
# 3  452444            0                    1.0           0.2174
# 4   99762            1                    1.0           0.2174
#
#    ATUALIZACAO_EMAIL  ATIVIDADE_EMAIL  EXPOSICAO_CONSUMIDOR_EMAILS  \
# 0             0.0000           0.4654                          1.0
# 1             0.1636           0.6402                          0.0
# 2             0.0000           1.0000                          1.0
# 3             0.1636           0.6402                          0.0
# 4             0.1636           0.6402                          0.0
#
#    CAD_DEMOGRAFICO_VAR_17  ATIVIDADE_TELEFONE  ATIVIDADE_ENDERECO  ...  \
# 0                  0.0008              0.8333              0.0685  ...
# ...

# %%
df.describe()
# Out:
#                CHAVE    IND_BOM_CLI  COMPARATIVO_RENDA_CEP  EXPOSICAO_EMAIL  \
# count  249910.000000  249910.000000          249910.000000    249910.000000
# mean   249857.469077       0.492341               0.143712         0.265542
# std    144192.873863       0.499942               0.299120         0.219735
# min         3.000000       0.000000               0.000000         0.000000
# 25%    125243.500000       0.000000               0.000000         0.217400
# 50%    249913.000000       0.000000               0.000000         0.217400
# 75%    374626.750000       1.000000               0.000000         0.217400
# max    499999.000000       1.000000               1.000000         1.000000
#
#        ATUALIZACAO_EMAIL  ATIVIDADE_EMAIL  EXPOSICAO_CONSUMIDOR_EMAILS  \
# count      249910.000000    249910.000000                249910.000000
# mean            0.231750         0.605052                     0.188440
# ...
